# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from statistics import harmonic_mean
from langdetect import detect
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer, CountVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('coursea_data.csv')  # Replace with the actual path if it's in a subfolder

# Drop the irrelevant columns
df.drop(['Unnamed: 0', 'course_organization'], axis=1, inplace=True)

# Display the DataFrame to check if it's loaded correctly
df.head()
# Out:
#                                         course_title course_Certificate_type  \
# 0  (ISC)² Systems Security Certified Practitioner...          SPECIALIZATION
# 1  A Crash Course in Causality:  Inferring Causal...                  COURSE
# 2                     A Crash Course in Data Science                  COURSE
# 3                            A Law Student's Toolkit                  COURSE
# 4                A Life of Happiness and Fulfillment                  COURSE
#
#    course_rating course_difficulty course_students_enrolled
# 0            4.7          Beginner                     5.3k
# 1            4.7      Intermediate                      17k
# 2            4.5             Mixed                     130k
# 3            4.7             Mixed                      91k
# 4            4.8             Mixed                     320k

# %%
df
# Out:
#                                           course_title  \
# 0    (ISC)² Systems Security Certified Practitioner...
# 1    A Crash Course in Causality:  Inferring Causal...
# 2                       A Crash Course in Data Science
# 3                              A Law Student's Toolkit
# 4                  A Life of Happiness and Fulfillment
# ..                                                 ...
# 886                         Программирование на Python
# 887               Психолингвистика (Psycholinguistics)
# 888       Разработка интерфейсов: вёрстка и JavaScript
# 889                            Русский как иностранный
# 890      Финансовые инструменты для частного инвестора
#
#     course_Certificate_type  course_rating course_difficulty  \
# 0            SPECIALIZATION            4.7          Beginner
# 1                    COURSE            4.7      Intermediate
# 2                    COURSE            4.5             Mixed
# 3                    COURSE            4.7             Mixed
# 4                    COURSE            4.8             Mixed
# ..                      ...            ...               ...
# 886          SPECIALIZATION            4.5      Intermediate
# 887                  COURSE            4.8             Mixed
# 888          SPECIALIZATION            4.5      Intermediate
# 889          SPECIALIZATION            4.6      Intermediate
# 890          SPECIALIZATION            4.7          Beginner
#
#     course_students_enrolled
# 0                       5.3k
# 1                        17k
# 2                       130k
# 3                        91k
# 4                       320k
# ..                       ...
# 886                      52k
# 887                      21k
# 888                      30k
# 889                     9.8k
# 890                      38k
#
# [891 rows x 5 columns]

# %%
df.course_students_enrolled.apply(lambda count : count[-1]).value_counts()
# Out:
# course_students_enrolled
# k    887
# m      4
# Name: count, dtype: int64

# %%
df = df[df.course_students_enrolled.str.endswith('k')]

# %%
df['course_students_enrolled'] = df['course_students_enrolled'].apply(lambda enrolled : eval(enrolled[:-1]) * 1000)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29136\4222749396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['course_students_enrolled'] = df['course_students_enrolled'].apply(lambda enrolled : eval(enrolled[:-1]) * 1000)
#                                           course_title  \
# 0    (ISC)² Systems Security Certified Practitioner...
# 1    A Crash Course in Causality:  Inferring Causal...
# 2                       A Crash Course in Data Science
# 3                              A Law Student's Toolkit
# 4                  A Life of Happiness and Fulfillment
# ..                                                 ...
# 886                         Программирование на Python
# 887               Психолингвистика (Psycholinguistics)
# 888       Разработка интерфейсов: вёрстка и JavaScript
# 889                            Русский как иностранный
# 890      Финансовые инструменты для частного инвестора
#
#     course_Certificate_type  course_rating course_difficulty  \
# 0            SPECIALIZATION            4.7          Beginner
# 1                    COURSE            4.7      Intermediate
# 2                    COURSE            4.5             Mixed
# 3                    COURSE            4.7             Mixed
# 4                    COURSE            4.8             Mixed
# ..                      ...            ...               ...
# 886          SPECIALIZATION            4.5      Intermediate
# 887                  COURSE            4.8             Mixed
# 888          SPECIALIZATION            4.5      Intermediate
# 889          SPECIALIZATION            4.6      Intermediate
# 890          SPECIALIZATION            4.7          Beginner
#
#      course_students_enrolled
# 0                      5300.0
# 1                     17000.0
# 2                    130000.0
# 3                     91000.0
# 4                    320000.0
# ..                        ...
# 886                   52000.0
# 887                   21000.0
# 888                   30000.0
# 889                    9800.0
# 890                   38000.0
#
# [887 rows x 5 columns]

# %%
minmax_scaler = MinMaxScaler()
scaled_ratings = minmax_scaler.fit_transform(df[['course_rating','course_students_enrolled']])

# %%
df['course_rating'] = scaled_ratings[:,0]
df['course_students_enrolled'] = scaled_ratings[:,1]
df['overall_rating'] = df[['course_rating','course_students_enrolled']].apply(lambda row : harmonic_mean(row), axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29136\2019104726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['course_rating'] = scaled_ratings[:,0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_29136\2019104726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['course_students_enrolled'] = scaled_ratings[:,1]
# C:\Users\HP\AppData\Local\Temp\ipykernel_29136\2019104726.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overall_rating'] = df[['course_rating','course_students_enrolled']].apply(lambda row : harmonic_mean(row), axis=1)

# %%
df
# Out:
#                                           course_title  \
# 0    (ISC)² Systems Security Certified Practitioner...
# 1    A Crash Course in Causality:  Inferring Causal...
# 2                       A Crash Course in Data Science
# 3                              A Law Student's Toolkit
# 4                  A Life of Happiness and Fulfillment
# ..                                                 ...
# 886                         Программирование на Python
# 887               Психолингвистика (Psycholinguistics)
# 888       Разработка интерфейсов: вёрстка и JavaScript
# 889                            Русский как иностранный
# 890      Финансовые инструменты для частного инвестора
#
#     course_Certificate_type  course_rating course_difficulty  \
# 0            SPECIALIZATION       0.823529          Beginner
# 1                    COURSE       0.823529      Intermediate
# 2                    COURSE       0.705882             Mixed
# 3                    COURSE       0.823529             Mixed
# 4                    COURSE       0.882353             Mixed
# ..                      ...            ...               ...
# 886          SPECIALIZATION       0.705882      Intermediate
# 887                  COURSE       0.882353             Mixed
# 888          SPECIALIZATION       0.705882      Intermediate
# 889          SPECIALIZATION       0.764706      Intermediate
# 890          SPECIALIZATION       0.823529          Beginner
#
#      course_students_enrolled  overall_rating
# 0                    0.004587        0.009122
# 1                    0.018709        0.036586
# 2                    0.155100        0.254319
# 3                    0.108027        0.190999
# 4                    0.384430        0.535534
# ..                        ...             ...
# 886                  0.060954        0.112217
# 887                  0.023537        0.045850
# 888                  0.034400        0.065602
# 889                  0.010018        0.019777
# 890                  0.044056        0.083637
#
# [887 rows x 6 columns]

# %%
df = df[df.course_title.apply(lambda title : detect(title) == 'en')]

# %%
vectorizer = TfidfVectorizer(stop_words='english')
vectors = vectorizer.fit_transform(df.course_title)

# %%
def recommend_by_course_title (title, recomm_count=10) : 
    title_vector = vectorizer.transform([title])
    cosine_sim = cosine_similarity(vectors, title_vector)
    idx = np.argsort(np.array(cosine_sim[:,0]))[-recomm_count:]
    sdf = df.iloc[idx].sort_values(by='overall_rating', ascending=False)
    return sdf

# %%
recommend_by_course_title('A Crash Course in Data Science')
# Out:
#                                           course_title  \
# 487             Introduction to Data Science in Python
# 486                       Introduction to Data Science
# 864                              What is Data Science?
# 54                                Applied Data Science
# 711                               SQL for Data Science
# 2                       A Crash Course in Data Science
# 825                             Tools for Data Science
# 171                             Crash Course on Python
# 1    A Crash Course in Causality:  Inferring Causal...
# 594                       Mathematics for Data Science
#
#     course_Certificate_type  course_rating course_difficulty  \
# 487                  COURSE       0.705882      Intermediate
# 486          SPECIALIZATION       0.764706          Beginner
# 864                  COURSE       0.823529          Beginner
# 54           SPECIALIZATION       0.764706          Beginner
# 711                  COURSE       0.764706          Beginner
# 2                    COURSE       0.705882             Mixed
# 825                  COURSE       0.764706          Beginner
# 171                  COURSE       0.882353          Beginner
# 1                    COURSE       0.823529      Intermediate
# 594          SPECIALIZATION       0.705882          Beginner
#
#      course_students_enrolled  overall_rating
# 487                  0.468920        0.563503
# 486                  0.372360        0.500843
# 864                  0.312010        0.452559
# 54                   0.263730        0.392199
# 711                  0.191310        0.306053
# 2                    0.155100        0.254319
# 825                  0.143030        0.240986
# 171                  0.095957        0.173089
# 1                    0.018709        0.036586
# 594                  0.012674        0.024900

# %%
recommend_by_course_title('machine learning')
# Out:
#                                           course_title  \
# 563                                   Machine Learning
# 200      Data Science: Statistics and Machine Learning
# 28                           Advanced Machine Learning
# 57                  Applied Machine Learning in Python
# 595                   Mathematics for Machine Learning
# 570                       Machine Learning with Python
# 568        Machine Learning for Business Professionals
# 566  Machine Learning and Reinforcement Learning in...
# 567                           Machine Learning for All
# 569                       Machine Learning for Trading
#
#     course_Certificate_type  course_rating course_difficulty  \
# 563          SPECIALIZATION       0.764706      Intermediate
# 200          SPECIALIZATION       0.647059      Intermediate
# 28           SPECIALIZATION       0.705882          Advanced
# 57                   COURSE       0.764706      Intermediate
# 595          SPECIALIZATION       0.764706          Beginner
# 570                  COURSE       0.823529      Intermediate
# 568                  COURSE       0.764706      Intermediate
# 566          SPECIALIZATION       0.235294      Intermediate
# 567                  COURSE       0.764706          Beginner
# 569          SPECIALIZATION       0.352941      Intermediate
#
#      course_students_enrolled  overall_rating
# 563                  0.348220        0.478533
# 200                  0.251660        0.362380
# 28                   0.227520        0.344122
# 57                   0.179240        0.290410
# 595                  0.179240        0.290410
# 570                  0.143030        0.243729
# 568                  0.068196        0.125224
# 566                  0.033193        0.058178
# 567                  0.021123        0.041110
# 569                  0.016295        0.031151

# %%
recommend_by_course_title('english')
# Out:
#                                   course_title course_Certificate_type  \
# 261             English for Career Development                  COURSE
# 18                   Academic English: Writing          SPECIALIZATION
# 260  English for Business and Entrepreneurship                  COURSE
# 259                      English Composition I                  COURSE
# 262                     English for Journalism                  COURSE
# 111      Business English Communication Skills          SPECIALIZATION
# 112               Business English: Networking                  COURSE
# 110                           Business English          SPECIALIZATION
# 548                              Learn English          SPECIALIZATION
# 810      The Pronunciation of American English          SPECIALIZATION
#
#      course_rating course_difficulty  course_students_enrolled  overall_rating
# 261       0.882353             Mixed                  0.915510        0.898626
# 18        0.823529          Beginner                  0.649970        0.726528
# 260       0.882353          Beginner                  0.275800        0.420243
# 259       0.764706          Beginner                  0.239590        0.364864
# 262       0.882353             Mixed                  0.155100        0.263824
# 111       0.823529      Intermediate                  0.143030        0.243729
# 112       0.823529      Intermediate                  0.091129        0.164099
# 110       0.823529      Intermediate                  0.044056        0.083637
# 548       0.588235          Beginner                  0.024744        0.047489
# 810       0.764706          Beginner                  0.000241        0.000483
